# %%
import pandas as pd
import numpy as np

# %%
#import column info
df_education_info = pd.read_csv("education_metadata.csv") 
df_education_info
# Out:
#              GEO_ID                                                 id
# 0              NAME                               Geographic Area Name
# 1    S1501_C01_001E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 2    S1501_C01_001M  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 3    S1501_C01_002E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 4    S1501_C01_002M  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# ..              ...                                                ...
# 764  S1501_C06_062M  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 765  S1501_C06_063E  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 766  S1501_C06_063M  Margin of Error!!Percent Female!!MEDIAN EARNIN...
# 767  S1501_C06_064E  Estimate!!Percent Female!!MEDIAN EARNINGS IN T...
# 768  S1501_C06_064M  Margin of Error!!Percent Female!!MEDIAN EARNIN...
#
# [769 rows x 2 columns]

# %%
#create filter for desired columns
education_rows = ["S1501_C01_006E", "S1501_C01_015E","S1501_C01_059E"]

# %%
#filter for desired columns
df_education_info = df_education_info[df_education_info["GEO_ID"].isin(education_rows)]
df_education_info
# Out:
#              GEO_ID                                                 id
# 11   S1501_C01_006E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 29   S1501_C01_015E  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 117  S1501_C01_059E  Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 1...

# %%
#clean column names
df_education_info['id'] = df_education_info.id.map(lambda x: x.lstrip("Estimate!!"))
df_education_info['id'] = df_education_info.id.replace("!!", " - ", regex=True)
df_education_info
# Out:
# <ipython-input-43-51579e90ca72>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_education_info['id'] = df_education_info.id.map(lambda x: x.lstrip("Estimate!!"))
# <ipython-input-43-51579e90ca72>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_education_info['id'] = df_education_info.id.replace("!!", " - ", regex=True)
#              GEO_ID                                                 id
# 11   S1501_C01_006E  Total - AGE BY EDUCATIONAL ATTAINMENT - Popula...
# 29   S1501_C01_015E  Total - AGE BY EDUCATIONAL ATTAINMENT - Popula...
# 117  S1501_C01_059E  Total - MEDIAN EARNINGS IN THE PAST 12 MONTHS ...

# %%
#create dictionary of new column names
df_education_column_key = df_education_info.set_index('GEO_ID').T.to_dict('records')
df_education_column_key = df_education_column_key[0]
df_education_column_key
# Out:
# {'S1501_C01_006E': 'Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over',
#  'S1501_C01_015E': "Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher",
#  'S1501_C01_059E': 'Total - MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings'}

# %%
#create lists of columns
df_education_numeric_columns = df_education_info.GEO_ID.tolist()
df_education_columns = []
for i in df_education_numeric_columns:
    df_education_columns.append(i)
df_education_columns.append("GEO_ID")
df_education_columns.append("NAME")
print(df_education_numeric_columns)
print(df_education_columns)
# Out:
# ['S1501_C01_006E', 'S1501_C01_015E', 'S1501_C01_059E']
# ['S1501_C01_006E', 'S1501_C01_015E', 'S1501_C01_059E', 'GEO_ID', 'NAME']

# %%
#import census age_gender data, with only desired columns
df_education = pd.read_csv("education_data_with_overlays.csv", usecols=df_education_columns)
df_education
# Out:
#                    GEO_ID                                            NAME  \
# 0                      id                            Geographic Area Name
# 1    1400000US36061000100       Census Tract 1, New York County, New York
# 2    1400000US36061000201    Census Tract 2.01, New York County, New York
# 3    1400000US36061000202    Census Tract 2.02, New York County, New York
# 4    1400000US36061000500       Census Tract 5, New York County, New York
# ..                    ...                                             ...
# 284  1400000US36061030900     Census Tract 309, New York County, New York
# 285  1400000US36061031100     Census Tract 311, New York County, New York
# 286  1400000US36061031703  Census Tract 317.03, New York County, New York
# 287  1400000US36061031704  Census Tract 317.04, New York County, New York
# 288  1400000US36061031900     Census Tract 319, New York County, New York
#
#                                         S1501_C01_006E  \
# 0    Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                                    0
# 2                                                 1871
# 3                                                 5945
# 4                                                    0
# ..                                                 ...
# 284                                               6962
# 285                                                  0
# 286                                               3765
# 287                                               7893
# 288                                                  0
#
#                                         S1501_C01_015E  \
# 0    Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                                    0
# 2                                                  310
# 3                                                 2021
# 4                                                    0
# ..                                                 ...
# 284                                               1373
# 285                                                  0
# 286                                               3103
# 287                                               7119
# 288                                                  0
#
#                                         S1501_C01_059E
# 0    Estimate!!Total!!MEDIAN EARNINGS IN THE PAST 1...
# 1                                                    -
# 2                                                29496
# 3                                                42013
# 4                                                    -
# ..                                                 ...
# 284                                              26041
# 285                                                  -
# 286                                             157464
# 287                                             128162
# 288                                                  -
#
# [289 rows x 5 columns]

# %%
#remove unneeded first row
df_education = df_education.iloc[1:] 
df_education
# Out:
#                    GEO_ID                                            NAME  \
# 1    1400000US36061000100       Census Tract 1, New York County, New York
# 2    1400000US36061000201    Census Tract 2.01, New York County, New York
# 3    1400000US36061000202    Census Tract 2.02, New York County, New York
# 4    1400000US36061000500       Census Tract 5, New York County, New York
# 5    1400000US36061000600       Census Tract 6, New York County, New York
# ..                    ...                                             ...
# 284  1400000US36061030900     Census Tract 309, New York County, New York
# 285  1400000US36061031100     Census Tract 311, New York County, New York
# 286  1400000US36061031703  Census Tract 317.03, New York County, New York
# 287  1400000US36061031704  Census Tract 317.04, New York County, New York
# 288  1400000US36061031900     Census Tract 319, New York County, New York
#
#     S1501_C01_006E S1501_C01_015E S1501_C01_059E
# 1                0              0              -
# 2             1871            310          29496
# 3             5945           2021          42013
# 4                0              0              -
# 5             8013           1408          27147
# ..             ...            ...            ...
# 284           6962           1373          26041
# 285              0              0              -
# 286           3765           3103         157464
# 287           7893           7119         128162
# 288              0              0              -
#
# [288 rows x 5 columns]

# %%
df_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 1 to 288
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   GEO_ID          288 non-null    object
#  1   NAME            288 non-null    object
#  2   S1501_C01_006E  288 non-null    object
#  3   S1501_C01_015E  288 non-null    object
#  4   S1501_C01_059E  288 non-null    object
# dtypes: object(5)
# memory usage: 11.4+ KB

# %%
#replace dashes in dataset with zeros
df_education = df_education.replace("-", 0)

# %%
#change quantitative data types in dataframe to numeric
df_education[df_education_numeric_columns] = df_education[df_education_numeric_columns].apply(pd.to_numeric)

# %%
#rename columns
df_education = df_education.rename(columns=df_education_column_key)
df_education
# Out:
#                    GEO_ID                                            NAME  \
# 1    1400000US36061000100       Census Tract 1, New York County, New York
# 2    1400000US36061000201    Census Tract 2.01, New York County, New York
# 3    1400000US36061000202    Census Tract 2.02, New York County, New York
# 4    1400000US36061000500       Census Tract 5, New York County, New York
# 5    1400000US36061000600       Census Tract 6, New York County, New York
# ..                    ...                                             ...
# 284  1400000US36061030900     Census Tract 309, New York County, New York
# 285  1400000US36061031100     Census Tract 311, New York County, New York
# 286  1400000US36061031703  Census Tract 317.03, New York County, New York
# 287  1400000US36061031704  Census Tract 317.04, New York County, New York
# 288  1400000US36061031900     Census Tract 319, New York County, New York
#
#      Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# 1                                                    0
# 2                                                 1871
# 3                                                 5945
# 4                                                    0
# 5                                                 8013
# ..                                                 ...
# 284                                               6962
# 285                                                  0
# 286                                               3765
# 287                                               7893
# 288                                                  0
#
#      Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# 1                                                    0
# 2                                                  310
# 3                                                 2021
# 4                                                    0
# 5                                                 1408
# ..                                                 ...
# 284                                               1373
# 285                                                  0
# 286                                               3103
# 287                                               7119
# 288                                                  0
#
#      Total - MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings
# 1                                                    0
# 2                                                29496
# 3                                                42013
# 4                                                    0
# 5                                                27147
# ..                                                 ...
# 284                                              26041
# 285                                                  0
# 286                                             157464
# 287                                             128162
# 288                                                  0
#
# [288 rows x 5 columns]

# %%
df_education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 1 to 288
# Data columns (total 5 columns):
#  #   Column                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                           --------------  -----
#  0   GEO_ID                                                                                                                           288 non-null    object
#  1   NAME                                                                                                                             288 non-null    object
#  2   Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over                                                             288 non-null    int64
#  3   Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher                               288 non-null    int64
#  4   Total - MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings  288 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 11.4+ KB

# %%
df_education.describe()
# Out:
#        Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over  \
# count                                         288.000000
# mean                                         4338.072917
# std                                          2460.338737
# min                                             0.000000
# 25%                                          2547.750000
# 50%                                          4070.000000
# 75%                                          5952.750000
# max                                         12937.000000
#
#        Total - AGE BY EDUCATIONAL ATTAINMENT - Population 25 years and over - Bachelor's degree or higher  \
# count                                         288.000000
# mean                                         2659.888889
# std                                          1950.509188
# min                                             0.000000
# 25%                                          1231.750000
# 50%                                          2035.000000
# 75%                                          3873.000000
# max                                         10280.000000
#
#        Total - MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) - Population 25 years and over with earnings
# count                                         288.000000
# mean                                        72595.906250
# std                                         37266.697163
# min                                             0.000000
# 25%                                         39246.500000
# 50%                                         74262.000000
# 75%                                        104363.000000
# max                                        201136.000000

# %%
import pickle

# %%
df_education.to_pickle("df_education.pkl")
