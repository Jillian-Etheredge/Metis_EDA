# %%
import pandas as pd
import numpy as np
import pickle

# %%
mta = pd.read_pickle("final_mta_v1.pkl")

# %%
mta
# Out:
#              STATION  DAILY_ENTRIES  NM_DAILY_ENTRIES
# 61    34 ST-PENN STA     11314018.0          1.000000
# 233  GRD CNTRL-42 ST      9793229.0          0.865583
# 59   34 ST-HERALD SQ      8354818.0          0.738447
# 46             23 ST      7881548.0          0.696617
# 68   42 ST-PORT AUTH      7092469.0          0.626873
# ..               ...            ...               ...
# 124  ASTORIA DITMARS      1152389.0          0.101851
# 88    61 ST WOODSIDE      1148506.0          0.101508
# 23            167 ST      1146475.0          0.101329
# 358         UTICA AV      1130547.0          0.099921
# 375  WORLD TRADE CTR      1126447.0          0.099558
#
# [100 rows x 3 columns]

# %%
subway = pd.read_csv('nyc_open_data_subway.csv', usecols = ["NAME"])
subway
# Out:
#                             NAME
# 0                       Astor Pl
# 1                       Canal St
# 2                        50th St
# 3                      Bergen St
# 4               Pennsylvania Ave
# ..                           ...
# 468  Coney Island - Stillwell Av
# 469       34th St - Hudson Yards
# 470                      72nd St
# 471                      86th St
# 472                      96th St
#
# [473 rows x 1 columns]

# %%
#create new field "STATION_CLEAN" to prepare strings for fuzzymerge
mta["STATION_CLEAN"] = mta["STATION"].str.title()
mta["STATION_CLEAN"] = mta["STATION_CLEAN"].str.replace("/", "-")
mta
# Out:
#              STATION  DAILY_ENTRIES  NM_DAILY_ENTRIES    STATION_CLEAN
# 61    34 ST-PENN STA     11314018.0          1.000000   34 St-Penn Sta
# 233  GRD CNTRL-42 ST      9793229.0          0.865583  Grd Cntrl-42 St
# 59   34 ST-HERALD SQ      8354818.0          0.738447  34 St-Herald Sq
# 46             23 ST      7881548.0          0.696617            23 St
# 68   42 ST-PORT AUTH      7092469.0          0.626873  42 St-Port Auth
# ..               ...            ...               ...              ...
# 124  ASTORIA DITMARS      1152389.0          0.101851  Astoria Ditmars
# 88    61 ST WOODSIDE      1148506.0          0.101508   61 St Woodside
# 23            167 ST      1146475.0          0.101329           167 St
# 358         UTICA AV      1130547.0          0.099921         Utica Av
# 375  WORLD TRADE CTR      1126447.0          0.099558  World Trade Ctr
#
# [100 rows x 4 columns]

# %%
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process

# %%
def fuzzy_merge(df_1, df_2, key1, key2, threshold=90, limit=2):
    """
    :param df_1: the left table to join
    :param df_2: the right table to join
    :param key1: key column of the left table
    :param key2: key column of the right table
    :param threshold: how close the matches should be to return a match, based on Levenshtein distance
    :param limit: the amount of matches that will get returned, these are sorted high to low
    :return: dataframe with boths keys and matches
    """
    s = df_2[key2].tolist()

    m = df_1[key1].apply(lambda x: process.extract(x, s, limit=limit))    
    df_1['matches'] = m

    m2 = df_1['matches'].apply(lambda x: ', '.join([i[0] for i in x if i[1] >= threshold]))
    df_1['matches'] = m2

    return df_1

# %%
#create function to add ordinal suffix to number
ordinal = lambda n: "%d%s" % (n,"tsnrhtdd"[(n//10%10!=1)*(n%10<4)*n%10::4])

# %%
#add ordinal suffix to street number (within string)
def insert_ordinal(string):
    a = []
    aa = []
    num_index = []
    for i in string:
        aa.append(i)
        if i.isdigit():
            a.append(i)
    for i in aa:
        if i.isdigit():
            num_index.append(aa.index(i))
    if a:
        c = ''.join([str(elem) for elem in a])
        cc = int(c)
        b = ordinal(cc)
        beg_ind = num_index[0]
        end_ind = num_index[-1]
        del aa[beg_ind:end_ind+1]
        aa.insert(beg_ind, b)
        bb = ''.join(aa)
        return bb
    else:
        return string

# %%
#Test function
insert_ordinal("57 AV")
# Out:
# '57th AV'

# %%
#Test function
insert_ordinal("St. George")
# Out:
# 'St. George'

# %%
mta["STATION_CLEAN"] = mta["STATION_CLEAN"].apply(insert_ordinal)

# %%
fuzmerge = fuzzy_merge(mta,subway, "STATION_CLEAN", "NAME", threshold=80, limit=1)

# %%
#export fuzmerge dataframe to a csv
# manually match stations where fuzzymerge failed
fuzmerge.to_csv("fuzmerge.csv")

# %%
#import manual match
fuzmerge_final = pd.read_excel("fuzmerge.xlsx", usecols = ["STATION", "DAILY_ENTRIES", "NM_DAILY_ENTRIES", "Unnamed: 6"])

# %%
fuzmerge_final.rename(columns={"Unnamed: 6":"name"}, inplace = True)

# %%
fuzmerge_final
# Out:
#             STATION  DAILY_ENTRIES  NM_DAILY_ENTRIES  \
# 0    34 ST-PENN STA       11314018          1.000000
# 1   GRD CNTRL-42 ST        9793229          0.865583
# 2   34 ST-HERALD SQ        8354818          0.738447
# 3             23 ST        7881548          0.696617
# 4   42 ST-PORT AUTH        7092469          0.626873
# ..              ...            ...               ...
# 95  ASTORIA DITMARS        1152389          0.101851
# 96   61 ST WOODSIDE        1148506          0.101508
# 97           167 ST        1146475          0.101329
# 98         UTICA AV        1130547          0.099921
# 99  WORLD TRADE CTR        1126447          0.099558
#
#                                  name
# 0              34th St - Penn Station
# 1             Grand Central - 42nd St
# 2                 Herald Sq - 34th St
# 3                             23rd St
# 4   42nd St - Port Authority Bus Term
# ..                                ...
# 95             Astoria - Ditmars Blvd
# 96                 Woodside - 61st St
# 97                           167th St
# 98                          Utica Ave
# 99                 World Trade Center
#
# [100 rows x 4 columns]

# %%
stations_w_data = pd.read_csv("https://raw.githubusercontent.com/dunleavyjason/project-1/Alexander/GeoSpatial%20Data/Stations_W_Data.csv", usecols = ["name", "geometry", "GEOID", "NAME_y", "Total Population - 25 years and over - Advanced Degrees", "Median Income - 25 years and over", "Total Female Population - 25 years and over"])

# %%
#drop duplicate stations - investigation indicated duplicates are due to multiple lines running through station
stations_w_data.drop_duplicates(subset = ["name"], inplace = True)

# %%
stations_w_data
# Out:
#                        name                                      geometry  \
# 0                  Astor Pl  POINT (-73.99106999861966 40.73005400028978)
# 1              8th St - NYU  POINT (-73.99250799849149 40.73046499853991)
# 2                  Canal St  POINT (-74.00019299927328 40.71880300107709)
# 5                 Spring St  POINT (-73.99714100006673 40.72230099999366)
# 6                   50th St  POINT (-73.98384899986625 40.76172799961419)
# ..                      ...                                           ...
# 139             Bleecker St  POINT (-73.99465900006331 40.72591466682659)
# 141                 8th Ave  POINT (-74.00257800104762 40.73977666638199)
# 142                110th St  POINT (-73.94424999687163 40.79502000011311)
# 146     5th Ave - Bryant Pk  POINT (-73.98196299856706 40.75382100064824)
# 148  34th St - Hudson Yards  POINT (-74.00219709442206 40.75544635961596)
#
#            GEOID                                         NAME_y  \
# 0    36061005700     Census Tract 57, New York County, New York
# 1    36061005700     Census Tract 57, New York County, New York
# 2    36061004500     Census Tract 45, New York County, New York
# 5    36061004500     Census Tract 45, New York County, New York
# 6    36061013100    Census Tract 131, New York County, New York
# ..           ...                                            ...
# 139  36061005502  Census Tract 55.02, New York County, New York
# 141  36061008300     Census Tract 83, New York County, New York
# 142  36061017200    Census Tract 172, New York County, New York
# 146  36061008400     Census Tract 84, New York County, New York
# 148  36061009900     Census Tract 99, New York County, New York
#
#      Total Population - 25 years and over - Advanced Degrees  \
# 0                                                 2106
# 1                                                 2106
# 2                                                  452
# 5                                                  452
# 6                                                 1827
# ..                                                 ...
# 139                                               1105
# 141                                               1932
# 142                                               1122
# 146                                               1222
# 148                                               3991
#
#      Median Income - 25 years and over  \
# 0                               125268
# 1                               125268
# 2                                90167
# 5                                90167
# 6                                95203
# ..                                 ...
# 139                             107250
# 141                              59348
# 142                              27269
# 146                             104282
# 148                             113702
#
#      Total Female Population - 25 years and over
# 0                                           1265
# 1                                           1265
# 2                                            347
# 5                                            347
# 6                                           1142
# ..                                           ...
# 139                                          703
# 141                                         1513
# 142                                         1835
# 146                                          753
# 148                                         2234
#
# [94 rows x 7 columns]

# %%
final_merge_v2 = pd.merge(fuzmerge_final, stations_w_data, on='name', how='inner')
final_merge_v2.head(50)
# Out:
#             STATION  DAILY_ENTRIES  NM_DAILY_ENTRIES  \
# 0    34 ST-PENN STA       11314018          1.000000
# 1   GRD CNTRL-42 ST        9793229          0.865583
# 2   34 ST-HERALD SQ        8354818          0.738447
# 3             23 ST        7881548          0.696617
# 4   42 ST-PORT AUTH        7092469          0.626873
# 5    14 ST-UNION SQ        7019937          0.620462
# 6    TIMES SQ-42 ST        6966121          0.615705
# 7         FULTON ST        6260737          0.553359
# 8             86 ST        5755149          0.508672
# 9       86 ST-2 AVE        1780128          0.157335
# 10           125 ST        5420482          0.479092
# 11         CANAL ST        5132496          0.453638
# 12   59 ST COLUMBUS        5010316          0.442839
# 13            14 ST        4295716          0.379678
# 14            96 ST        4238098          0.374586
# 15      96 ST-2 AVE        1325118          0.117118
# 16      CHAMBERS ST        3867234          0.341806
# 17   47-50 STS ROCK        3796085          0.335518
# 18     PATH NEW WTC        3722245          0.328991
# 19  WORLD TRADE CTR        1126447          0.099558
# 20            50 ST        3430367          0.303193
# 21            72 ST        3334128          0.294687
# 22      72 ST-2 AVE        2027803          0.179226
# 23            28 ST        3221278          0.284713
# 24   W 4 ST-WASH SQ        3008833          0.265935
# 25          WALL ST        2723948          0.240756
# 26  42 ST-BRYANT PK        2695076          0.238204
# 27             7 AV        2659977          0.235101
# 28  LEXINGTON AV/53        2652924          0.234478
# 29           145 ST        2461610          0.217568
# 30             8 AV        2444135          0.216024
# 31       57 ST-7 AV        2407017          0.212743
# 32           116 ST        2258014          0.199573
# 33         GRAND ST        2127812          0.188065
# 34           103 ST        2053852          0.181528
# 35    103 ST-CORONA        1344796          0.118857
# 36            77 ST        2050295          0.181214
# 37    BOWLING GREEN        1884546          0.166564
# 38            33 ST        1880083          0.166169
# 39  THIRTY THIRD ST        1611617          0.142441
# 40   DELANCEY/ESSEX        1836426          0.162311
# 41        SPRING ST        1749362          0.154615
# 42            49 ST        1586267          0.140200
# 43    66 ST-LINCOLN        1526963          0.134958
# 44           181 ST        1516836          0.134063
# 45   68ST-HUNTER CO        1462670          0.129276
# 46  B'WAY-LAFAYETTE        1461310          0.129156
# 47  34 ST-HUDSON YD        1452484          0.128376
# 48  LEXINGTON AV/63        1441317          0.127389
# 49            79 ST        1424978          0.125944
#
#                                  name  \
# 0              34th St - Penn Station
# 1             Grand Central - 42nd St
# 2                 Herald Sq - 34th St
# 3                             23rd St
# 4   42nd St - Port Authority Bus Term
# 5                  Union Sq - 14th St
# 6                  Times Sq - 42nd St
# 7                           Fulton St
# 8                             86th St
# 9                             86th St
# 10                           125th St
# 11                           Canal St
# 12          59th St - Columbus Circle
# 13                            14th St
# 14                            96th St
# 15                            96th St
# 16                        Chambers St
# 17    47th-50th Sts - Rockefeller Ctr
# 18                 World Trade Center
# 19                 World Trade Center
# 20                            50th St
# 21                            72nd St
# 22                            72nd St
# 23                            28th St
# 24   W 4th St - Washington Sq (Lower)
# 25                            Wall St
# 26                42nd St - Bryant Pk
# 27                            7th Ave
# 28            Lexington Ave - 53rd St
# 29                           145th St
# 30                            8th Ave
# 31                            57th St
# 32                           116th St
# 33                           Grand St
# 34                           103rd St
# 35                           103rd St
# 36                            77th St
# 37                      Bowling Green
# 38                            33rd St
# 39                            33rd St
# 40             Delancey St - Essex St
# 41                          Spring St
# 42                            49th St
# 43              66th St - Lincoln Ctr
# 44                           181st St
# 45           68th St - Hunter College
# 46            Broadway - Lafayette St
# 47             34th St - Hudson Yards
# 48            Lexington Ave - 63rd St
# 49                            79th St
#
#                                         geometry        GEOID  \
# 0   POINT (-73.99105699913983 40.75037300003949)  36061010100
# 1   POINT (-73.97671329925841 40.75180742981634)  36061009200
# 2    POINT (-73.9879368338264 40.74964456009442)  36061010100
# 3    POINT (-73.98659900207888 40.7398640004746)  36061006800
# 4    POINT (-73.98973500085859 40.7573079985515)  36061011900
# 5   POINT (-73.98995099881881 40.73467300099612)  36061005200
# 6   POINT (-73.98676800153976 40.75461199851542)  36061011300
# 7   POINT (-74.00762309323994 40.71016216530185)  36061001501
# 8   POINT (-73.96882849429672 40.78582304678557)  36061014300
# 9   POINT (-73.96882849429672 40.78582304678557)  36061014300
# 10  POINT (-73.94549500011411 40.80775399918281)  36061020000
# 11  POINT (-74.00019299927328 40.71880300107709)  36061004500
# 12  POINT (-73.98192900232715 40.76824700063689)  36061014500
# 13  POINT (-73.99620899921355 40.73822799969515)  36061008100
# 14   POINT (-73.9510700015425 40.78567199998607)  36061015801
# 15   POINT (-73.9510700015425 40.78567199998607)  36061015801
# 16  POINT (-74.00858473570133 40.71411100077403)  36061002100
# 17  POINT (-73.98133100227702 40.75864100159815)  36061009600
# 18  POINT (-74.00974461517701 40.71256392680817)  36061002100
# 19  POINT (-74.00974461517701 40.71256392680817)  36061002100
# 20  POINT (-73.98384899986625 40.76172799961419)  36061013100
# 21    POINT (-73.976336575218 40.77551939729258)  36061014300
# 22    POINT (-73.976336575218 40.77551939729258)  36061014300
# 23  POINT (-73.98426400110407 40.74306999925903)  36061006800
# 24  POINT (-74.00030814755975 40.73225449336788)  36061006500
# 25  POINT (-74.01186199860112 40.70755700086603)  36061000700
# 26  POINT (-73.98459099904711 40.75418400131255)  36061011300
# 27  POINT (-73.98169782344476 40.76297015245628)  36061013100
# 28  POINT (-73.96907237490204 40.75746830782865)  36061009800
# 29  POINT (-73.95035999879713 40.82655099962194)  36061022900
# 30  POINT (-74.00257800104762 40.73977666638199)  36061008300
# 31  POINT (-73.97736800085171 40.76408500081713)  36061011201
# 32    POINT (-73.94962500096905 40.802097999133)  36061019000
# 33  POINT (-73.99375299913589 40.71826699954992)  36061001800
# 34  POINT (-73.96137008267617 40.79606073990453)  36061014300
# 35  POINT (-73.96137008267617 40.79606073990453)  36061014300
# 36  POINT (-73.95987399886047 40.77362000074615)  36061012800
# 37  POINT (-74.01400799803432 40.70491399928076)  36061001300
# 38  POINT (-73.98207600148947 40.74608099909145)  36061007400
# 39  POINT (-73.98207600148947 40.74608099909145)  36061007400
# 40  POINT (-73.98740940202974 40.71830605618619)  36061001800
# 41  POINT (-73.99714100006673 40.72230099999366)  36061004500
# 42  POINT (-73.98420956591096 40.75980197387069)  36061012500
# 43  POINT (-73.98220899995783 40.77344000052039)  36061014900
# 44   POINT (-73.9335959996056 40.84950499974065)  36061026900
# 45  POINT (-73.96387000158042 40.76814100049679)  36061012000
# 46  POINT (-73.99620399876055 40.72529699873805)  36061005502
# 47  POINT (-74.00219709442206 40.75544635961596)  36061009900
# 48  POINT (-73.96608964413245 40.76461809442373)  36061011402
# 49  POINT (-73.97991700056134 40.78393399959032)  36061016700
#
#                                             NAME_y  \
# 0      Census Tract 101, New York County, New York
# 1       Census Tract 92, New York County, New York
# 2      Census Tract 101, New York County, New York
# 3       Census Tract 68, New York County, New York
# 4      Census Tract 119, New York County, New York
# 5       Census Tract 52, New York County, New York
# 6      Census Tract 113, New York County, New York
# 7    Census Tract 15.01, New York County, New York
# 8      Census Tract 143, New York County, New York
# 9      Census Tract 143, New York County, New York
# 10     Census Tract 200, New York County, New York
# 11      Census Tract 45, New York County, New York
# 12     Census Tract 145, New York County, New York
# 13      Census Tract 81, New York County, New York
# 14  Census Tract 158.01, New York County, New York
# 15  Census Tract 158.01, New York County, New York
# 16      Census Tract 21, New York County, New York
# 17      Census Tract 96, New York County, New York
# 18      Census Tract 21, New York County, New York
# 19      Census Tract 21, New York County, New York
# 20     Census Tract 131, New York County, New York
# 21     Census Tract 143, New York County, New York
# 22     Census Tract 143, New York County, New York
# 23      Census Tract 68, New York County, New York
# 24      Census Tract 65, New York County, New York
# 25       Census Tract 7, New York County, New York
# 26     Census Tract 113, New York County, New York
# 27     Census Tract 131, New York County, New York
# 28      Census Tract 98, New York County, New York
# 29     Census Tract 229, New York County, New York
# 30      Census Tract 83, New York County, New York
# 31  Census Tract 112.01, New York County, New York
# 32     Census Tract 190, New York County, New York
# 33      Census Tract 18, New York County, New York
# 34     Census Tract 143, New York County, New York
# 35     Census Tract 143, New York County, New York
# 36     Census Tract 128, New York County, New York
# 37      Census Tract 13, New York County, New York
# 38      Census Tract 74, New York County, New York
# 39      Census Tract 74, New York County, New York
# 40      Census Tract 18, New York County, New York
# 41      Census Tract 45, New York County, New York
# 42     Census Tract 125, New York County, New York
# 43     Census Tract 149, New York County, New York
# 44     Census Tract 269, New York County, New York
# 45     Census Tract 120, New York County, New York
# 46   Census Tract 55.02, New York County, New York
# 47      Census Tract 99, New York County, New York
# 48  Census Tract 114.02, New York County, New York
# 49     Census Tract 167, New York County, New York
#
#     Total Population - 25 years and over - Advanced Degrees  \
# 0                                                 799
# 1                                                1152
# 2                                                 799
# 3                                                4182
# 4                                                 347
# 5                                                1910
# 6                                                  39
# 7                                                3843
# 8                                                   0
# 9                                                   0
# 10                                               1183
# 11                                                452
# 12                                               3856
# 13                                               5539
# 14                                               3867
# 15                                               3867
# 16                                               4300
# 17                                                149
# 18                                               4300
# 19                                               4300
# 20                                               1827
# 21                                                  0
# 22                                                  0
# 23                                               4182
# 24                                               3748
# 25                                               5803
# 26                                                 39
# 27                                               1827
# 28                                               4795
# 29                                               2015
# 30                                               1932
# 31                                                540
# 32                                               1501
# 33                                               2008
# 34                                                  0
# 35                                                  0
# 36                                               3439
# 37                                               3251
# 38                                               3071
# 39                                               3071
# 40                                               2008
# 41                                                452
# 42                                               1551
# 43                                               3446
# 44                                               1263
# 45                                               2134
# 46                                               1105
# 47                                               3991
# 48                                               1375
# 49                                               4203
#
#     Median Income - 25 years and over  \
# 0                               89375
# 1                              113281
# 2                               89375
# 3                              105560
# 4                               22131
# 5                              133245
# 6                               91250
# 7                               80574
# 8                                   0
# 9                                   0
# 10                              47882
# 11                              90167
# 12                             150978
# 13                             110921
# 14                             108390
# 15                             108390
# 16                             151061
# 17                             105000
# 18                             151061
# 19                             151061
# 20                              95203
# 21                                  0
# 22                                  0
# 23                             105560
# 24                              95236
# 25                             113125
# 26                              91250
# 27                              95203
# 28                             106491
# 29                              27955
# 30                              59348
# 31                              86830
# 32                              56139
# 33                              48994
# 34                                  0
# 35                                  0
# 36                             106170
# 37                             104606
# 38                             103189
# 39                             103189
# 40                              48994
# 41                              90167
# 42                             109529
# 43                             108048
# 44                              25814
# 45                             109858
# 46                             107250
# 47                             113702
# 48                             107778
# 49                             131133
#
#     Total Female Population - 25 years and over
# 0                                           456
# 1                                           703
# 2                                           456
# 3                                          2852
# 4                                           423
# 5                                          1024
# 6                                            21
# 7                                          3017
# 8                                             1
# 9                                             1
# 10                                         1525
# 11                                          347
# 12                                         2444
# 13                                         3058
# 14                                         2176
# 15                                         2176
# 16                                         2261
# 17                                           46
# 18                                         2261
# 19                                         2261
# 20                                         1142
# 21                                            1
# 22                                            1
# 23                                         2852
# 24                                         2520
# 25                                         3524
# 26                                           21
# 27                                         1142
# 28                                         3156
# 29                                         3347
# 30                                         1513
# 31                                          440
# 32                                         1405
# 33                                         2522
# 34                                            1
# 35                                            1
# 36                                         2273
# 37                                         2024
# 38                                         1791
# 39                                         1791
# 40                                         2522
# 41                                          347
# 42                                          925
# 43                                         2320
# 44                                         2718
# 45                                         1582
# 46                                          703
# 47                                         2234
# 48                                          827
# 49                                         2694

# %%
final_merge_v2.reindex()
# Out:
#             STATION  DAILY_ENTRIES  NM_DAILY_ENTRIES  \
# 0    34 ST-PENN STA       11314018          1.000000
# 1   GRD CNTRL-42 ST        9793229          0.865583
# 2   34 ST-HERALD SQ        8354818          0.738447
# 3             23 ST        7881548          0.696617
# 4   42 ST-PORT AUTH        7092469          0.626873
# ..              ...            ...               ...
# 56             1 AV        1231084          0.108807
# 57         8 ST-NYU        1211944          0.107115
# 58         ASTOR PL        1194662          0.105588
# 59  WHITEHALL S-FRY        1176768          0.104006
# 60             2 AV        1160443          0.102563
#
#                                  name  \
# 0              34th St - Penn Station
# 1             Grand Central - 42nd St
# 2                 Herald Sq - 34th St
# 3                             23rd St
# 4   42nd St - Port Authority Bus Term
# ..                                ...
# 56                            1st Ave
# 57                       8th St - NYU
# 58                           Astor Pl
# 59                       Whitehall St
# 60          Lower East Side - 2nd Ave
#
#                                         geometry        GEOID  \
# 0   POINT (-73.99105699913983 40.75037300003949)  36061010100
# 1   POINT (-73.97671329925841 40.75180742981634)  36061009200
# 2    POINT (-73.9879368338264 40.74964456009442)  36061010100
# 3    POINT (-73.98659900207888 40.7398640004746)  36061006800
# 4    POINT (-73.98973500085859 40.7573079985515)  36061011900
# ..                                           ...          ...
# 56  POINT (-73.98168087489128 40.73097497580066)  36061003400
# 57  POINT (-73.99250799849149 40.73046499853991)  36061005700
# 58  POINT (-73.99106999861966 40.73005400028978)  36061005700
# 59   POINT (-74.0130072374272 40.70314237359914)  36061000900
# 60  POINT (-73.98993800003434 40.72340166574911)  36061003602
#
#                                            NAME_y  \
# 0     Census Tract 101, New York County, New York
# 1      Census Tract 92, New York County, New York
# 2     Census Tract 101, New York County, New York
# 3      Census Tract 68, New York County, New York
# 4     Census Tract 119, New York County, New York
# ..                                            ...
# 56     Census Tract 34, New York County, New York
# 57     Census Tract 57, New York County, New York
# 58     Census Tract 57, New York County, New York
# 59      Census Tract 9, New York County, New York
# 60  Census Tract 36.02, New York County, New York
#
#     Total Population - 25 years and over - Advanced Degrees  \
# 0                                                 799
# 1                                                1152
# 2                                                 799
# 3                                                4182
# 4                                                 347
# ..                                                ...
# 56                                               3296
# 57                                               2106
# 58                                               2106
# 59                                               1305
# 60                                               1675
#
#     Median Income - 25 years and over  \
# 0                               89375
# 1                              113281
# 2                               89375
# 3                              105560
# 4                               22131
# ..                                ...
# 56                              80142
# 57                             125268
# 58                             125268
# 59                             117578
# 60                              63819
#
#     Total Female Population - 25 years and over
# 0                                           456
# 1                                           703
# 2                                           456
# 3                                          2852
# 4                                           423
# ..                                          ...
# 56                                         2588
# 57                                         1265
# 58                                         1265
# 59                                          673
# 60                                         1095
#
# [61 rows x 10 columns]

# %%
final_merge_v2.to_csv("final_merge_v2.csv")
